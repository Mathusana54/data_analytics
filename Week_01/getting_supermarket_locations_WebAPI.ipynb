# %% [markdown]
# # Getting all available Swiss supermarkets using the overpass Web API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import requests
import json
import folium
from pandas import json_normalize

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Show current working directory
print(os.getcwd())
# Out:
# /workspaces/data_analytics/Week_01

# %% [markdown]
# ## Overpass turbo query to get all available supermarkets in Switzerland

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["shop"="supermarket"](area);
        out;"""

# Web API request
# Web API request
r = requests.post(url, data={'data': query}, headers={'User-Agent': 'ZHAW student exercise'}, timeout=200)
print(r.status_code)
print(r.text[:500])
data = r.json()['elements']


# Save data to file
with open('supermarkets.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = json_normalize(data)

# Number of rows and columns
print(df.shape)

# First rows
df.head()
# Out:
# 200
# {
#   "version": 0.6,
#   "generator": "Overpass API 0.7.62.11 87bfad18",
#   "osm3s": {
#     "timestamp_osm_base": "2026-09-17T17:48:02Z",
#     "timestamp_areas_base": "2026-09-16T16:46:29Z",
#     "copyright": "The data included in this document is from www.openstreetmap.org. The data is made available under ODbL."
#   },
#   "elements": [
#
# {
#   "type": "node",
#   "id": 33126515,
#   "lat": 47.1556157,
#   "lon": 9.0379152,
#   "tags": {
#     "addr:city": "Schänis",
#     "addr:country": "CH",
#     "addr:housenumber":
# (3478, 299)
#    type        id        lat       lon tags.addr:city tags.addr:country  \
# 0  node  33126515  47.155616  9.037915        Schänis                CH
# 1  node  36726161  47.228183  8.965330         Uznach               NaN
# 2  node  39768209  47.225154  8.969868         Uznach               NaN
# 3  node  39947904  47.376732  8.542161         Zürich                CH
# 4  node  48932835  47.375020  8.522895         Zürich               NaN
#
#   tags.addr:housenumber tags.addr:postcode  tags.addr:street tags.brand  ...  \
# 0                    32               8718    Biltnerstrasse       Spar  ...
# 1                     4               8730  Wiesentalstrasse     Migros  ...
# 2                   NaN               8730               NaN       Coop  ...
# 3                     1               8001     Bahnhofbrücke       Coop  ...
# 4                     7               8004      Wengistrasse     Migros  ...
#
#   tags.diet:organic tags.diet:seafood tags.recycling:low_energy_bulbs  \
# 0               NaN               NaN                             NaN
# 1               NaN               NaN                             NaN
# 2               NaN               NaN                             NaN
# 3               NaN               NaN                             NaN
# 4               NaN               NaN                             NaN
#
#   tags.opening_hours:cafe tags.payment:discover_card tags.name:zh-Hans  \
# 0                     NaN                        NaN               NaN
# 1                     NaN                        NaN               NaN
# 2                     NaN                        NaN               NaN
# 3                     NaN                        NaN               NaN
# 4                     NaN                        NaN               NaN
#
#   tags.panoramax tags.ramp:wheelchair tags.wheelchair:description:de  \
# 0            NaN                  NaN                            NaN
# 1            NaN                  NaN                            NaN
# 2            NaN                  NaN                            NaN
# 3            NaN                  NaN                            NaN
# 4            NaN                  NaN                            NaN
#
#   tags.wheelchair:description:en
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
# [5 rows x 299 columns]

# %% [markdown]
# ## Plot supermarkets on map

# %%
# Subset of supermarkets by brand
locations = df[["lat", "lon", "tags.brand", "tags.shop"]].loc[df["tags.brand"].isin(['Migros', 'Coop'])]
print(locations.head(5))

# Create map
map = folium.Map(location=[locations.lat.mean(), 
                           locations.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in locations.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]], 
                  popup=location_info["tags.brand"]).add_to(map)

# Plot map
map
# Out:
#          lat       lon tags.brand    tags.shop
# 1  47.228183  8.965330     Migros  supermarket
# 2  47.225154  8.969868       Coop  supermarket
# 3  47.376732  8.542161       Coop  supermarket
# 4  47.375020  8.522895     Migros  supermarket
# 5  47.491874  8.706448     Migros  supermarket
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_91154a390102d3b268d7cf3b91835da3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_91154a390102d3b268d7cf3b91835da3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_91154a390102d3b268d7cf3b91835da3 = L.map(
#                 &quot;map_91154a390102d3b268d7cf3b91835da3&quot;,
#                 {
#                     center: [47.00547458701195, 7.994371212589642],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_91154a390102d3b268d7cf3b91835da3);
#
#
#
#
#
#             var tile_layer_f52f14e93d7b944aad9e843555826ae4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f52f14e93d7b944aad9e843555826ae4.addTo(map_91154a390102d3b268d7cf3b91835da3);
#
#
#             var marker_b73221f4af1372892dc9c97e9dbaa008 = L.marker(
#                 [47.2281827, 8.9653298],
#                 {}
#             ).addTo(map_91154a390102d3b268d7cf3b91835da3);
#
#
#         var popup_41d5b8e97785e4051cde8fe2c17a86c7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_62279ace990d42b6a775dc6429a249f0 = $(`&lt;div id=&quot;html_62279ace990d42b6a775dc6429a249f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_41d5b8e97785e4051cde8fe2c17a86c7.setContent(html_62279ace990d42b6a775dc6429a249f0);
#
#
#
#         marker_b73221f4af1372892dc9c97e9dbaa008.bindPopup(popup_41d5b8e97785e4051cde8fe2c17a86c7)
#         ;
#
#
#
#
#             var marker_85451a446f2baa6c8b327ba3d3034817 = L.marker(
#                 [47.2251539, 8.9698681],
#                 {}
#             ).addTo(map_91154a390102d3b268d7cf3b91835da3);
#
#
#         var popup_833035a87528b9b889ab4729fafc53b9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3608dd70194f677c9b39d56986539137 = $(`&lt;div id=&quot;html_3608dd70194f677c9b39d56986539137&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_833035a87528b9b889ab4729fafc53b9.setContent(html_3608dd70194f677c9b39d56986539137);
#
#
#
#         marker_85451a446f2baa6c8b327ba3d3034817.bindPopup(popup_833035a87528b9b889ab4729fafc53b9)
#         ;
#
#
#
#
#             var marker_d42ddae0407dfd6568eec15d27791021 = L.marker(
#                 [47.3767316, 8.5421608],
#                 {}
#             ).addTo(map_91154a390102d3b268d7cf3b91835da3);
#
#
#         var popup_48bf3b0e705d5d26323ea18abc0be281 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5834dab3fd31e027f754c04161b4ab7c = $(`&lt;div id=&quot;html_5834dab3fd31e027f754c04161b4ab7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Coop&lt;/div&gt;`)[0];
#                 popup_48bf3b0e705d5d26323ea18abc0be281.setContent(html_5834dab3fd31e027f754c04161b4ab7c);
#
#
#
#         marker_d42ddae0407dfd6568eec15d27791021.bindPopup(popup_48bf3b0e705d5d26323ea18abc0be281)
#         ;
#
#
#
#
#             var marker_3daace14febba38e16b0bd04ab648618 = L.marker(
#                 [47.37502, 8.522895],
#                 {}
#             ).addTo(map_91154a390102d3b268d7cf3b91835da3);
#
#
#         var popup_d10e306df38cba7f669ce2c495edb827 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ea65473712014761bac3d84acf3b8326 = $(`&lt;div id=&quot;html_ea65473712014761bac3d84acf3b8326&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_d10e306df38cba7f669ce2c495edb827.setContent(html_ea65473712014761bac3d84acf3b8326);
#
#
#
#         marker_3daace14febba38e16b0bd04ab648618.bindPopup(popup_d10e306df38cba7f669ce2c495edb827)
#         ;
#
#
#
#
#             var marker_21ca751bb26dbb2082bd24d965b3a894 = L.marker(
#                 [47.4918744, 8.7064484],
#                 {}
#             ).addTo(map_91154a390102d3b268d7cf3b91835da3);
#
#
#         var popup_0466d3ad76fe8bda2f76936613af81be = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_37513f103bee8bc3f9e94410a9771c94 = $(`&lt;div id=&quot;html_37513f103bee8bc3f9e94410a9771c94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migros&lt;/div&gt;`)[0];
#                 popup_0466d3ad76fe8bda2f76936613af81be.setContent(html_37513f103bee8bc3f9e94410a9771c94);
#
#
#
#         marker_21ca751bb26dbb2082bd24d965b3a894.bindPopup(popup_0466d3ad76fe8bda2f76936613af81be)
#         ;
#
#
#
#
#             var marker_b79911b0e2f7d2ebfe5d52849fb3745d = L.marker(
#                 [47.3400698, 8.5305461],
#                 {}

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.8.0-1064-azure
# Datetime: 2026-09-17 17:50:14
# Python Version: 3.11.16
# -----------------------------------
